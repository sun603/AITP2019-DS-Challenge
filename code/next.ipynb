# %%
import pandas as pd

# %%
stn = "/home/glentner/public/datasets/noaa/gsod.stn.csv"
obs = "/home/glentner/public/datasets/noaa/gsod.obs.csv"

# %%
pdstn = pd.read_csv(stn)

# %%
indn = pdstn[pdstn['state'] == 'IN']

# %%
instaid = indn["station_id"].tolist()

# %%
indn.min()
# Out:
# station_id                    692644
# wban_id                          167
# station_name    ANDERSON MUNI DARLIN
# country                           US
# state                             IN
# call_name                        inf
# latitude                      38.044
# longitude                    -87.521
# elevation                       17.5
# date_start                  19411101
# date_end                    19450907
# dtype: object

# %%
indn[indn["date_start"] == 19411101]
# Out:
#       station_id  wban_id                   station_name country state  \
# 28712     725330    14827  FORT WAYNE INTERNATIONAL AIRP      US    IN
#
#       call_name  latitude  longitude  elevation  date_start  date_end
# 28712      KFWA    40.971    -85.206      241.1    19411101  20190304

# %%
data_frame = pd.read_csv("new.csv", names=["station_id", "wban_id", "datetime", "measure_id", "measure_value", "measure_ref"])

# %%
data_frame2 = pd.read_csv("new2.csv", names=["station_id", "wban_id", "datetime", "measure_id", "measure_value", "measure_ref"])

# %%
max_tempo = data_frame[data_frame["measure_id"] == 9]
max_tempo["measure_value"].max()
# Out:
# 127.4

# %%
max_wind = data_frame[data_frame["measure_id"] == 8]
max_wind["measure_value"].max()
# Out:
# 85.5

# %%
max_pre = data_frame[data_frame["measure_id"] == 11]
max_pre["measure_value"].max()
# Out:
# 99.99

# %%
data_frame.head()
# Out:
#    station_id  wban_id    datetime  measure_id  measure_value  measure_ref
# 0      725330    14827  1949/01/04           4          988.2           23
# 1      725330    14827  1949/01/04          18            0.0            0
# 2      725330    14827  1949/01/04          15            0.0            0
# 3      725330    14827  1949/01/04          13            1.0            0
# 4      725330    14827  1949/01/04           5            2.7           24

# %%
data_frame.min()
# Out:
# station_id           692644
# wban_id                 167
# datetime         1949-04-01
# measure_id                1
# measure_value         -37.5
# measure_ref               0
# dtype: object

# %%
data_frame[data_frame["station_id"] == 725330]
# Out:
#          station_id  wban_id    datetime  measure_id  measure_value  \
# 0            725330    14827  1949/01/04           4         988.20
# 1            725330    14827  1949/01/04          18           0.00
# 2            725330    14827  1949/01/04          15           0.00
# 3            725330    14827  1949/01/04          13           1.00
# 4            725330    14827  1949/01/04           5           2.70
# 5            725330    14827  1949/01/04           7          14.00
# 6            725330    14827  1949/01/04           1          37.00
# 7            725330    14827  1949/01/04          14           1.00
# 8            725330    14827  1949/01/04           9          48.40
# 9            725330    14827  1949/01/04           2          34.80
# 10           725330    14827  1949/01/04           6           6.30
# 11           725330    14827  1949/01/04          17           0.00
# 12           725330    14827  1949/01/04          11           1.06
# ...

# %%
data_frame2.min()
# Out:
# station_id           692644
# wban_id                 167
# datetime         1949-04-01
# measure_id                1
# measure_value         -37.5
# measure_ref               0
# dtype: object
